# %%
# Import the pathlib to csv library

from pathlib import Path
import csv
import os
import numpy as np

# Set the file path
csvpath = Path(".\\Resouces\\data.csv")


# Initialize vairble to hold profit_loss
data = []


# Initialize line number vairable 
line_number = 0


# Open the input path as a file object
with open(csvpath, 'r') as csvfile:
    

    # Print the datatype of the file object
    print(type(csvfile))
    
   
    # Pass in the csv file to the csv.read() function
    # Use ',' as delimiter
    csvreader = csv.reader(csvfile, delimiter = ',')
    
   
    # Print the datatype of the csvreader
    print(type(csvreader))
    
    
    # Go to the next row from the start of the file
    # Iterate line_number by 1
    header = next(csvreader)
    line_number += 1
    
    # Print header
#    print(f"{header} HEADER")
    
    # Read each row of data after the header
#    for row in csvreader:
    # PRINT ROW
#        print(row)
    # SET VAIRABLE
#        profit_loss = int(row[1])
    # APPEND THE ROW PROFIT_LOSS TO LIST
#    data.append(profit_loss)


        # Initialize metric variables
total_months = 0
net_total_profit_loss = {0}
average_change = 0
greatest_increase = 0
greatest_decrease = 0
average_change = 0
total_profit_loss = 0
last_profit_loss = 0
monthly_change = []
greatest_increase_month = []
greatest_decrease_month = []


# For 


with open(csvpath, 'r') as csvfile:
    for row in csvfile:
        total_months += 1
    print(row[1])
    net_total_profit_loss += (float(row[1]))
    data.append(row[1])
    key, value = row[0], row[1]
    data_dict[key] = int(value)
    
for key, value in data_dict.items():
    if greatest_decrease == 0:
        greatest_decrease = value
    elif value < greatest_decrease:
        greatest_decrease = value
        greatest_decrease_key = key
    if greatest_increase == 0:
        greatest_increase = value
    elif value > greatest_increase:
        greatest_increase = value
        greatest_increase_key = key
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-b869ced83813> in <module>
#      19
#      20 # Open the input path as a file object
# ---> 21 with open(csvpath, 'r') as csvfile:
#      22
#      23
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Resouces\\data.csv'
